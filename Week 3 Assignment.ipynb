# %% [markdown]
# ## Load a graph database

# %%
I selected the dataset that represents a collection of Facebook pages. Nodes specify the pages and edges represent mutual likes among pages.

# %% [markdown]
# ## Visualization the graph

# %%
USING PERIODIC COMMIT
LOAD CSV WITH HEADERS FROM "https://raw.githubusercontent.com/olga0503/DATA-620/master/athletes_edges.csv" AS csvLine
merge (n:node_1{node_1: csvLine.node_1})
merge (m:node_2 {node_2: csvLine.node_2})
merge (n)-[r:Likes]-(m)
RETURN *
LIMIT 1000

# %%
from IPython.display import Image
Image(filename="x.png")

# %% [markdown]
# ## Calculate graph’s diameter

# %%
MATCH (n), (m) 
WHERE id(n) <> id(m)
MATCH p=shortestPath((n)-[*]-(m))
RETURN n as beginning_pasth,m as end_path,length(p) AS legth_path, nodes(p) AS path
ORDER BY len DESC 
LIMIT 1

# %%
from IPython.display import Image
Image(filename="x2.png")

# %% [markdown]
# ## Calculate other graph's metrics

# %% [markdown]
# 1. Count number of nodes

# %%
match (n)
return count(n)

# %%
from IPython.display import Image
Image(filename="x4.png")

# %% [markdown]
# 2. Count number of edges

# %%
match (n)-[r]->()
return count(r)

# %%
from IPython.display import Image
Image(filename="x5.png")

# %% [markdown]
# 3. Find leaf nodes

# %%
match (n)-[r]->(m)
where not ((m)-->()) return distinct m

# %%
from IPython.display import Image
Image(filename="x6.png")

# %% [markdown]
# 4. Finf root nodes

# %%
match (m)-[r]->(n)
where not (()-->(m)) return distinct m

# %%
from IPython.display import Image
Image(filename="x7.png")

# %% [markdown]
# 5. Find degree of all nodes

# %%
match (n)-[r]-()
return n, count(distinct r) as degree
order by degree desc

# %%
from IPython.display import Image
Image(filename="x3.png")
